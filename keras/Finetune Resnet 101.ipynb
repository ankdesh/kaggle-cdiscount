# %%
import pandas as pd
import numpy as np
import os.path

from keras.preprocessing.image import Iterator
from keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
from keras.models import load_model

from flyyufelix_models.resnet_101 import resnet101_model

import threading
lock = threading.Lock()

from keras.callbacks import ModelCheckpoint

from BsonIterator import BSONIterator
# Out:
# Using TensorFlow backend.

# %%
METADATA_DIR = 'metadata'
DATA_DIR = '../../dataset'

train_offsets_df = pd.read_csv(os.path.join(METADATA_DIR,"train_offsets.csv"), index_col=0)
train_images_df = pd.read_csv(os.path.join(METADATA_DIR,"RandomSplit_Train_0.5_0.1.csv"), index_col=0)
val_images_df = pd.read_csv(os.path.join(METADATA_DIR,"RandomSplit_Val_0.5_0.1.csv"), index_col=0)

num_classes = 5270
num_train_images = len(train_images_df)
num_val_images = len(val_images_df)
batch_size = 32

# Create a generator for training and a generator for validation.
# Tip: use ImageDataGenerator for data augmentation and preprocessing.
assert os.path.exists(os.path.join(DATA_DIR, 'train.bson'))
train_bson_file = open(os.path.join(DATA_DIR, 'train.bson'), "rb")
train_datagen = ImageDataGenerator()
train_gen = BSONIterator(train_bson_file, train_images_df, train_offsets_df,
                         num_classes, train_datagen, lock, target_size = (224,224),
                         batch_size=batch_size, shuffle=True)

val_datagen = ImageDataGenerator()
val_gen = BSONIterator(train_bson_file, val_images_df, train_offsets_df,
                       num_classes, val_datagen, lock, target_size = (224,224),
                       batch_size=batch_size, shuffle=True)
# Out:
# /home/ankdesh/virtualenvs/cdiscount-py2.7/local/lib/python2.7/site-packages/numpy/lib/arraysetops.py:463: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# Found 5570369 images belonging to 5270 classes.
# Found 614245 images belonging to 5270 classes.

# %%
from keras.callbacks import ModelCheckpoint

# Save model Dir
MODEL_DIR = 'saved_models'
IMAGE_ROWS = 224
IMAGE_COLS = 224
CHANNELS =3

# Checkpointer 
checkpointer = ModelCheckpoint(filepath='saved_models/Resnet101.{epoch:02d}-{acc:.2f}-{val_acc:.2f}_RandomSplit_Train_0.5_0.1.h5', verbose=1)

# create the base pre-trained model
model = resnet101_model(IMAGE_ROWS,IMAGE_COLS,CHANNELS,num_classes)
# Out:
# flyyufelix_models/resnet_101.py:123: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (7, 7), strides=(2, 2), use_bias=False, name="conv1")`
#   x = Convolution2D(64, 7, 7, subsample=(2, 2), name='conv1', bias=False)(x)
# flyyufelix_models/resnet_101.py:70: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (1, 1), strides=(1, 1), use_bias=False, name="res2a_branch2a")`
#   name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:77: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), use_bias=False, name="res2a_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:82: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res2a_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:87: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), strides=(1, 1), use_bias=False, name="res2a_branch1")`
#   name=conv_name_base + '1', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:91: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   x = merge([x, shortcut], mode='sum', name='res' + str(stage) + block)
# /home/ankdesh/virtualenvs/cdiscount-py2.7/local/lib/python2.7/site-packages/keras/legacy/layers.py:458: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (1, 1), use_bias=False, name="res2b_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), use_bias=False, name="res2b_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res2b_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:48: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   x = merge([x, input_tensor], mode='sum', name='res' + str(stage) + block)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (1, 1), use_bias=False, name="res2c_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), use_bias=False, name="res2c_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res2c_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:70: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), strides=(2, 2), use_bias=False, name="res3a_branch2a")`
#   name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:77: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), use_bias=False, name="res3a_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:82: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (1, 1), use_bias=False, name="res3a_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:87: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (1, 1), strides=(2, 2), use_bias=False, name="res3a_branch1")`
#   name=conv_name_base + '1', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="res3b1_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), use_bias=False, name="res3b1_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (1, 1), use_bias=False, name="res3b1_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="res3b2_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), use_bias=False, name="res3b2_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (1, 1), use_bias=False, name="res3b2_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="res3b3_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), use_bias=False, name="res3b3_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (1, 1), use_bias=False, name="res3b3_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:70: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), strides=(2, 2), use_bias=False, name="res4a_branch2a")`
#   name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:77: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4a_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:82: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4a_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:87: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), strides=(2, 2), use_bias=False, name="res4a_branch1")`
#   name=conv_name_base + '1', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b1_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b1_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b1_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b2_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b2_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b2_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b3_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b3_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b3_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b4_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b4_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b4_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b5_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b5_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b5_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b6_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b6_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b6_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b7_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b7_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b7_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b8_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b8_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b8_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b9_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b9_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b9_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b10_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b10_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b10_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b11_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b11_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b11_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b12_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b12_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b12_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b13_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b13_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b13_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b14_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b14_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b14_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b15_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b15_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b15_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b16_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b16_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b16_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b17_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b17_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b17_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b18_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b18_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b18_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b19_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b19_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b19_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b20_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b20_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b20_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b21_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b21_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b21_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="res4b22_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), use_bias=False, name="res4b22_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1024, (1, 1), use_bias=False, name="res4b22_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:70: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (1, 1), strides=(2, 2), use_bias=False, name="res5a_branch2a")`
#   name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:77: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), use_bias=False, name="res5a_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:82: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(2048, (1, 1), use_bias=False, name="res5a_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:87: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(2048, (1, 1), strides=(2, 2), use_bias=False, name="res5a_branch1")`
#   name=conv_name_base + '1', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (1, 1), use_bias=False, name="res5b_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), use_bias=False, name="res5b_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(2048, (1, 1), use_bias=False, name="res5b_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)
# flyyufelix_models/resnet_101.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (1, 1), use_bias=False, name="res5c_branch2a")`
#   x = Convolution2D(nb_filter1, 1, 1, name=conv_name_base + '2a', bias=False)(input_tensor)
# flyyufelix_models/resnet_101.py:39: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), use_bias=False, name="res5c_branch2b")`
#   name=conv_name_base + '2b', bias=False)(x)
# flyyufelix_models/resnet_101.py:44: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(2048, (1, 1), use_bias=False, name="res5c_branch2c")`
#   x = Convolution2D(nb_filter3, 1, 1, name=conv_name_base + '2c', bias=False)(x)

# %%
for layer in model.layers[:483]:
    layer.trainable = False
for layer in model.layers[483:]:
    layer.trainable = True

# %%
# compile the model (should be done *after* setting layers to non-trainable)
# model.compile(optimizer='rmsprop', loss='categorical_crossentropy')
from keras.optimizers import SGD
opt = SGD(lr=1e-3, decay=0.0, momentum=0.9, nesterov=True)
model.compile(optimizer=opt,
              loss="categorical_crossentropy",
              metrics=["accuracy"])

# %%
from keras.callbacks import TensorBoard
tb = TensorBoard()

# %%
num_epochs = 2


# train the model on the new data for a few epochs
model.fit_generator(train_gen,
                    steps_per_epoch = num_train_images // batch_size,
                    epochs = num_epochs,
                    validation_data = val_gen,
                    validation_steps = num_val_images // batch_size,
                    workers = 4, callbacks=[checkpointer])
# Out:
# Epoch 1/2
# 174073/174074 [============================>.] - ETA: 0s - loss: 3.3013 - acc: 0.4193Epoch 00000: saving model to saved_models/Resnet101.00-0.42-0.48_RandomSplit_Train_0.5_0.1.h5
# 174074/174074 [==============================] - ETA: 0s - loss: 3.3013 - acc: 0.4193 - val_loss: 2.7919 - val_acc: 0.4830
# Epoch 2/2
# 174073/174074 [============================>.] - ETA: 0s - loss: 2.6878 - acc: 0.4929Epoch 00001: saving model to saved_models/Resnet101.01-0.49-0.51_RandomSplit_Train_0.5_0.1.h5
# 174074/174074 [==============================] - ETA: 0s - loss: 2.6878 - acc: 0.4929 - val_loss: 2.5943 - val_acc: 0.5123

# %%
num_epochs = 2


# train the model on the new data for a few epochs
model.fit_generator(train_gen,
                    steps_per_epoch = num_train_images // batch_size,
                    epochs = num_epochs,
                    validation_data = val_gen,
                    validation_steps = num_val_images // batch_size,
                    workers = 4, callbacks=[checkpointer])
# Out:
# Epoch 1/2
# 136670/174074 [======================>.......] - ETA: 10312s - loss: 2.4990 - acc: 0.5172

# %%
for i,layer in enumerate(model.layers):
    print (i, layer.name)
# Out:
# (0, 'data')
# (1, 'conv1_zeropadding')
# (2, 'conv1')
# (3, 'bn_conv1')
# (4, 'scale_conv1')
# (5, 'conv1_relu')
# (6, 'pool1')
# (7, 'res2a_branch2a')
# (8, 'bn2a_branch2a')
# (9, 'scale2a_branch2a')
# (10, 'res2a_branch2a_relu')
# (11, 'res2a_branch2b_zeropadding')
# (12, 'res2a_branch2b')
# (13, 'bn2a_branch2b')
# (14, 'scale2a_branch2b')
# (15, 'res2a_branch2b_relu')
# (16, 'res2a_branch2c')
# (17, 'res2a_branch1')
# (18, 'bn2a_branch2c')
# (19, 'bn2a_branch1')
# (20, 'scale2a_branch2c')
# (21, 'scale2a_branch1')
# (22, 'res2a')
# (23, 'res2a_relu')
# (24, 'res2b_branch2a')
# (25, 'bn2b_branch2a')
# (26, 'scale2b_branch2a')
# (27, 'res2b_branch2a_relu')
# (28, 'res2b_branch2b_zeropadding')
# (29, 'res2b_branch2b')
# (30, 'bn2b_branch2b')
# (31, 'scale2b_branch2b')
# (32, 'res2b_branch2b_relu')
# (33, 'res2b_branch2c')
# (34, 'bn2b_branch2c')
# (35, 'scale2b_branch2c')
# (36, 'res2b')
# (37, 'res2b_relu')
# (38, 'res2c_branch2a')
# (39, 'bn2c_branch2a')
# (40, 'scale2c_branch2a')
# (41, 'res2c_branch2a_relu')
# (42, 'res2c_branch2b_zeropadding')
# (43, 'res2c_branch2b')
# (44, 'bn2c_branch2b')
# (45, 'scale2c_branch2b')
# (46, 'res2c_branch2b_relu')
# (47, 'res2c_branch2c')
# (48, 'bn2c_branch2c')
# (49, 'scale2c_branch2c')
# (50, 'res2c')
# (51, 'res2c_relu')
# (52, 'res3a_branch2a')
# (53, 'bn3a_branch2a')
# (54, 'scale3a_branch2a')
# (55, 'res3a_branch2a_relu')
# (56, 'res3a_branch2b_zeropadding')
# (57, 'res3a_branch2b')
# (58, 'bn3a_branch2b')
# (59, 'scale3a_branch2b')
# (60, 'res3a_branch2b_relu')
# (61, 'res3a_branch2c')
# (62, 'res3a_branch1')
# (63, 'bn3a_branch2c')
# (64, 'bn3a_branch1')
# (65, 'scale3a_branch2c')
# (66, 'scale3a_branch1')
# (67, 'res3a')
# (68, 'res3a_relu')
# (69, 'res3b1_branch2a')
# (70, 'bn3b1_branch2a')
# (71, 'scale3b1_branch2a')
# (72, 'res3b1_branch2a_relu')
# (73, 'res3b1_branch2b_zeropadding')
# (74, 'res3b1_branch2b')
# (75, 'bn3b1_branch2b')
# (76, 'scale3b1_branch2b')
# (77, 'res3b1_branch2b_relu')
# (78, 'res3b1_branch2c')
# (79, 'bn3b1_branch2c')
# (80, 'scale3b1_branch2c')
# (81, 'res3b1')
# (82, 'res3b1_relu')
# (83, 'res3b2_branch2a')
# (84, 'bn3b2_branch2a')
# (85, 'scale3b2_branch2a')
# (86, 'res3b2_branch2a_relu')
# (87, 'res3b2_branch2b_zeropadding')
# (88, 'res3b2_branch2b')
# (89, 'bn3b2_branch2b')
# (90, 'scale3b2_branch2b')
# (91, 'res3b2_branch2b_relu')
# (92, 'res3b2_branch2c')
# (93, 'bn3b2_branch2c')
# (94, 'scale3b2_branch2c')
# (95, 'res3b2')
# (96, 'res3b2_relu')
# (97, 'res3b3_branch2a')
# (98, 'bn3b3_branch2a')
# (99, 'scale3b3_branch2a')
# (100, 'res3b3_branch2a_relu')
# (101, 'res3b3_branch2b_zeropadding')
# (102, 'res3b3_branch2b')
# (103, 'bn3b3_branch2b')
# (104, 'scale3b3_branch2b')
# (105, 'res3b3_branch2b_relu')
# (106, 'res3b3_branch2c')
# (107, 'bn3b3_branch2c')
# (108, 'scale3b3_branch2c')
# (109, 'res3b3')
# (110, 'res3b3_relu')
# (111, 'res4a_branch2a')
# (112, 'bn4a_branch2a')
# (113, 'scale4a_branch2a')
# (114, 'res4a_branch2a_relu')
# (115, 'res4a_branch2b_zeropadding')
# (116, 'res4a_branch2b')
# (117, 'bn4a_branch2b')
# (118, 'scale4a_branch2b')
# (119, 'res4a_branch2b_relu')
# (120, 'res4a_branch2c')
# (121, 'res4a_branch1')
# (122, 'bn4a_branch2c')
# (123, 'bn4a_branch1')
# (124, 'scale4a_branch2c')
# (125, 'scale4a_branch1')
# (126, 'res4a')
# (127, 'res4a_relu')
# (128, 'res4b1_branch2a')
# (129, 'bn4b1_branch2a')
# (130, 'scale4b1_branch2a')
# (131, 'res4b1_branch2a_relu')
# (132, 'res4b1_branch2b_zeropadding')
# (133, 'res4b1_branch2b')
# (134, 'bn4b1_branch2b')
# (135, 'scale4b1_branch2b')
# (136, 'res4b1_branch2b_relu')
# (137, 'res4b1_branch2c')
# (138, 'bn4b1_branch2c')
# (139, 'scale4b1_branch2c')
# (140, 'res4b1')
# (141, 'res4b1_relu')
# (142, 'res4b2_branch2a')
# (143, 'bn4b2_branch2a')
# (144, 'scale4b2_branch2a')
# (145, 'res4b2_branch2a_relu')
# (146, 'res4b2_branch2b_zeropadding')
# (147, 'res4b2_branch2b')
# (148, 'bn4b2_branch2b')
# (149, 'scale4b2_branch2b')
# (150, 'res4b2_branch2b_relu')
# (151, 'res4b2_branch2c')
# (152, 'bn4b2_branch2c')
# (153, 'scale4b2_branch2c')
# (154, 'res4b2')
# (155, 'res4b2_relu')
# (156, 'res4b3_branch2a')
# (157, 'bn4b3_branch2a')
# (158, 'scale4b3_branch2a')
# (159, 'res4b3_branch2a_relu')
# (160, 'res4b3_branch2b_zeropadding')
# (161, 'res4b3_branch2b')
# (162, 'bn4b3_branch2b')
# (163, 'scale4b3_branch2b')
# (164, 'res4b3_branch2b_relu')
# (165, 'res4b3_branch2c')
# (166, 'bn4b3_branch2c')
# (167, 'scale4b3_branch2c')
# (168, 'res4b3')
# (169, 'res4b3_relu')
# (170, 'res4b4_branch2a')
# (171, 'bn4b4_branch2a')
# (172, 'scale4b4_branch2a')
# (173, 'res4b4_branch2a_relu')
# (174, 'res4b4_branch2b_zeropadding')
# (175, 'res4b4_branch2b')
# (176, 'bn4b4_branch2b')
# (177, 'scale4b4_branch2b')
# (178, 'res4b4_branch2b_relu')
# (179, 'res4b4_branch2c')
# (180, 'bn4b4_branch2c')
# (181, 'scale4b4_branch2c')
# (182, 'res4b4')
# (183, 'res4b4_relu')
# (184, 'res4b5_branch2a')
# (185, 'bn4b5_branch2a')
# (186, 'scale4b5_branch2a')
# (187, 'res4b5_branch2a_relu')
# (188, 'res4b5_branch2b_zeropadding')
# (189, 'res4b5_branch2b')
# (190, 'bn4b5_branch2b')
# (191, 'scale4b5_branch2b')
# (192, 'res4b5_branch2b_relu')
# (193, 'res4b5_branch2c')
# (194, 'bn4b5_branch2c')
# (195, 'scale4b5_branch2c')
# (196, 'res4b5')
# (197, 'res4b5_relu')
# (198, 'res4b6_branch2a')
# (199, 'bn4b6_branch2a')
# (200, 'scale4b6_branch2a')
# (201, 'res4b6_branch2a_relu')
# (202, 'res4b6_branch2b_zeropadding')
# (203, 'res4b6_branch2b')
# (204, 'bn4b6_branch2b')
# (205, 'scale4b6_branch2b')
# (206, 'res4b6_branch2b_relu')
# (207, 'res4b6_branch2c')
# (208, 'bn4b6_branch2c')
# (209, 'scale4b6_branch2c')
# (210, 'res4b6')
# (211, 'res4b6_relu')
# (212, 'res4b7_branch2a')
# (213, 'bn4b7_branch2a')
# (214, 'scale4b7_branch2a')
# (215, 'res4b7_branch2a_relu')
# (216, 'res4b7_branch2b_zeropadding')
# (217, 'res4b7_branch2b')
# (218, 'bn4b7_branch2b')
# (219, 'scale4b7_branch2b')
# (220, 'res4b7_branch2b_relu')
# (221, 'res4b7_branch2c')
# (222, 'bn4b7_branch2c')
# (223, 'scale4b7_branch2c')
# (224, 'res4b7')
# (225, 'res4b7_relu')
# (226, 'res4b8_branch2a')
# (227, 'bn4b8_branch2a')
# (228, 'scale4b8_branch2a')
# (229, 'res4b8_branch2a_relu')
# (230, 'res4b8_branch2b_zeropadding')
# (231, 'res4b8_branch2b')
# (232, 'bn4b8_branch2b')
# (233, 'scale4b8_branch2b')
# (234, 'res4b8_branch2b_relu')
# (235, 'res4b8_branch2c')
# (236, 'bn4b8_branch2c')
# (237, 'scale4b8_branch2c')
# (238, 'res4b8')
# (239, 'res4b8_relu')
# (240, 'res4b9_branch2a')
# (241, 'bn4b9_branch2a')
# (242, 'scale4b9_branch2a')
# (243, 'res4b9_branch2a_relu')
# (244, 'res4b9_branch2b_zeropadding')
# (245, 'res4b9_branch2b')
# (246, 'bn4b9_branch2b')
# (247, 'scale4b9_branch2b')
# (248, 'res4b9_branch2b_relu')
# (249, 'res4b9_branch2c')
# (250, 'bn4b9_branch2c')
# (251, 'scale4b9_branch2c')
# (252, 'res4b9')
# (253, 'res4b9_relu')
# (254, 'res4b10_branch2a')
# (255, 'bn4b10_branch2a')
# (256, 'scale4b10_branch2a')
# (257, 'res4b10_branch2a_relu')
# (258, 'res4b10_branch2b_zeropadding')
# (259, 'res4b10_branch2b')
# (260, 'bn4b10_branch2b')
# (261, 'scale4b10_branch2b')
# (262, 'res4b10_branch2b_relu')
# (263, 'res4b10_branch2c')
# (264, 'bn4b10_branch2c')
# (265, 'scale4b10_branch2c')
# (266, 'res4b10')
# (267, 'res4b10_relu')
# (268, 'res4b11_branch2a')
# (269, 'bn4b11_branch2a')
# (270, 'scale4b11_branch2a')
# (271, 'res4b11_branch2a_relu')
# (272, 'res4b11_branch2b_zeropadding')
# (273, 'res4b11_branch2b')
# (274, 'bn4b11_branch2b')
# (275, 'scale4b11_branch2b')
# (276, 'res4b11_branch2b_relu')
# (277, 'res4b11_branch2c')
# (278, 'bn4b11_branch2c')
# (279, 'scale4b11_branch2c')
# (280, 'res4b11')
# (281, 'res4b11_relu')
# (282, 'res4b12_branch2a')
# (283, 'bn4b12_branch2a')
# (284, 'scale4b12_branch2a')
# (285, 'res4b12_branch2a_relu')
# (286, 'res4b12_branch2b_zeropadding')
# (287, 'res4b12_branch2b')
# (288, 'bn4b12_branch2b')
# (289, 'scale4b12_branch2b')
# (290, 'res4b12_branch2b_relu')
# (291, 'res4b12_branch2c')
# (292, 'bn4b12_branch2c')
# (293, 'scale4b12_branch2c')
# (294, 'res4b12')
# (295, 'res4b12_relu')
# (296, 'res4b13_branch2a')
# (297, 'bn4b13_branch2a')
# (298, 'scale4b13_branch2a')
# (299, 'res4b13_branch2a_relu')
# (300, 'res4b13_branch2b_zeropadding')
# (301, 'res4b13_branch2b')
# (302, 'bn4b13_branch2b')
# (303, 'scale4b13_branch2b')
# (304, 'res4b13_branch2b_relu')
# (305, 'res4b13_branch2c')
# (306, 'bn4b13_branch2c')
# (307, 'scale4b13_branch2c')
# (308, 'res4b13')
# (309, 'res4b13_relu')
# (310, 'res4b14_branch2a')
# (311, 'bn4b14_branch2a')
# (312, 'scale4b14_branch2a')
# (313, 'res4b14_branch2a_relu')
# (314, 'res4b14_branch2b_zeropadding')
# (315, 'res4b14_branch2b')
# (316, 'bn4b14_branch2b')
# (317, 'scale4b14_branch2b')
# (318, 'res4b14_branch2b_relu')
# (319, 'res4b14_branch2c')
# (320, 'bn4b14_branch2c')
# (321, 'scale4b14_branch2c')
# (322, 'res4b14')
# (323, 'res4b14_relu')
# (324, 'res4b15_branch2a')
# (325, 'bn4b15_branch2a')
# (326, 'scale4b15_branch2a')
# (327, 'res4b15_branch2a_relu')
# (328, 'res4b15_branch2b_zeropadding')
# (329, 'res4b15_branch2b')
# (330, 'bn4b15_branch2b')
# (331, 'scale4b15_branch2b')
# (332, 'res4b15_branch2b_relu')
# (333, 'res4b15_branch2c')
# (334, 'bn4b15_branch2c')
# (335, 'scale4b15_branch2c')
# (336, 'res4b15')
# (337, 'res4b15_relu')
# (338, 'res4b16_branch2a')
# (339, 'bn4b16_branch2a')
# (340, 'scale4b16_branch2a')
# (341, 'res4b16_branch2a_relu')
# (342, 'res4b16_branch2b_zeropadding')
# (343, 'res4b16_branch2b')
# (344, 'bn4b16_branch2b')
# (345, 'scale4b16_branch2b')
# (346, 'res4b16_branch2b_relu')
# (347, 'res4b16_branch2c')
# (348, 'bn4b16_branch2c')
# (349, 'scale4b16_branch2c')
# (350, 'res4b16')
# (351, 'res4b16_relu')
# (352, 'res4b17_branch2a')
# (353, 'bn4b17_branch2a')
# (354, 'scale4b17_branch2a')
# (355, 'res4b17_branch2a_relu')
# (356, 'res4b17_branch2b_zeropadding')
# (357, 'res4b17_branch2b')
# (358, 'bn4b17_branch2b')
# (359, 'scale4b17_branch2b')
# (360, 'res4b17_branch2b_relu')
# (361, 'res4b17_branch2c')
# (362, 'bn4b17_branch2c')
# (363, 'scale4b17_branch2c')
# (364, 'res4b17')
# (365, 'res4b17_relu')
# (366, 'res4b18_branch2a')
# (367, 'bn4b18_branch2a')
# (368, 'scale4b18_branch2a')
# (369, 'res4b18_branch2a_relu')
# (370, 'res4b18_branch2b_zeropadding')
# (371, 'res4b18_branch2b')
# (372, 'bn4b18_branch2b')
# (373, 'scale4b18_branch2b')
# (374, 'res4b18_branch2b_relu')
# (375, 'res4b18_branch2c')
# (376, 'bn4b18_branch2c')
# (377, 'scale4b18_branch2c')
# (378, 'res4b18')
# (379, 'res4b18_relu')
# (380, 'res4b19_branch2a')
# (381, 'bn4b19_branch2a')
# (382, 'scale4b19_branch2a')
# (383, 'res4b19_branch2a_relu')
# (384, 'res4b19_branch2b_zeropadding')
# (385, 'res4b19_branch2b')
# (386, 'bn4b19_branch2b')
# (387, 'scale4b19_branch2b')
# (388, 'res4b19_branch2b_relu')
# (389, 'res4b19_branch2c')
# (390, 'bn4b19_branch2c')
# (391, 'scale4b19_branch2c')
# (392, 'res4b19')
# (393, 'res4b19_relu')
# (394, 'res4b20_branch2a')
# (395, 'bn4b20_branch2a')
# (396, 'scale4b20_branch2a')
# (397, 'res4b20_branch2a_relu')
# (398, 'res4b20_branch2b_zeropadding')
# (399, 'res4b20_branch2b')
# (400, 'bn4b20_branch2b')
# (401, 'scale4b20_branch2b')
# (402, 'res4b20_branch2b_relu')
# (403, 'res4b20_branch2c')
# (404, 'bn4b20_branch2c')
# (405, 'scale4b20_branch2c')
# (406, 'res4b20')
# (407, 'res4b20_relu')
# (408, 'res4b21_branch2a')
# (409, 'bn4b21_branch2a')
# (410, 'scale4b21_branch2a')
# (411, 'res4b21_branch2a_relu')
# (412, 'res4b21_branch2b_zeropadding')
# (413, 'res4b21_branch2b')
# (414, 'bn4b21_branch2b')
# (415, 'scale4b21_branch2b')
# (416, 'res4b21_branch2b_relu')
# (417, 'res4b21_branch2c')
# (418, 'bn4b21_branch2c')
# (419, 'scale4b21_branch2c')
# (420, 'res4b21')
# (421, 'res4b21_relu')
# (422, 'res4b22_branch2a')
# (423, 'bn4b22_branch2a')
# (424, 'scale4b22_branch2a')
# (425, 'res4b22_branch2a_relu')
# (426, 'res4b22_branch2b_zeropadding')
# (427, 'res4b22_branch2b')
# (428, 'bn4b22_branch2b')
# (429, 'scale4b22_branch2b')
# (430, 'res4b22_branch2b_relu')
# (431, 'res4b22_branch2c')
# (432, 'bn4b22_branch2c')
# (433, 'scale4b22_branch2c')
# (434, 'res4b22')
# (435, 'res4b22_relu')
# (436, 'res5a_branch2a')
# (437, 'bn5a_branch2a')
# (438, 'scale5a_branch2a')
# (439, 'res5a_branch2a_relu')
# (440, 'res5a_branch2b_zeropadding')
# (441, 'res5a_branch2b')
# (442, 'bn5a_branch2b')
# (443, 'scale5a_branch2b')
# (444, 'res5a_branch2b_relu')
# (445, 'res5a_branch2c')
# (446, 'res5a_branch1')
# (447, 'bn5a_branch2c')
# (448, 'bn5a_branch1')
# (449, 'scale5a_branch2c')
# (450, 'scale5a_branch1')
# (451, 'res5a')
# (452, 'res5a_relu')
# (453, 'res5b_branch2a')
# (454, 'bn5b_branch2a')
# (455, 'scale5b_branch2a')
# (456, 'res5b_branch2a_relu')
# (457, 'res5b_branch2b_zeropadding')
# (458, 'res5b_branch2b')
# (459, 'bn5b_branch2b')
# (460, 'scale5b_branch2b')
# (461, 'res5b_branch2b_relu')
# (462, 'res5b_branch2c')
# (463, 'bn5b_branch2c')
# (464, 'scale5b_branch2c')
# (465, 'res5b')
# (466, 'res5b_relu')
# (467, 'res5c_branch2a')
# (468, 'bn5c_branch2a')
# (469, 'scale5c_branch2a')
# (470, 'res5c_branch2a_relu')
# (471, 'res5c_branch2b_zeropadding')
# (472, 'res5c_branch2b')
# (473, 'bn5c_branch2b')
# (474, 'scale5c_branch2b')
# (475, 'res5c_branch2b_relu')
# (476, 'res5c_branch2c')
# (477, 'bn5c_branch2c')
# (478, 'scale5c_branch2c')
# (479, 'res5c')
# (480, 'res5c_relu')
# (481, 'avg_pool')
# (482, 'flatten_2')
# (483, 'fc1')
# (484, 'fc2')
# (485, 'fc8')
